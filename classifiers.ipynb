# %%
from sklearn import datasets
import numpy as np

# %%
iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target
print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
  X, y, test_size=0.3, random_state=1, stratify=y
)

# %%
print('Labels counts in y:', np.bincount(y))
print('Labels counts in y_train:', np.bincount(y_train))
print('Labels counts in y_test:', np.bincount(y_test))
# Out:
# Labels counts in y: [50 50 50]
# Labels counts in y_train: [35 35 35]
# Labels counts in y_test: [15 15 15]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(eta0=0.1, random_state=1)
ppn.fit(X_train_std, y_train)
# Out:
# Perceptron(eta0=0.1, random_state=1)

# %%
y_pred = ppn.predict(X_test_std)
print('Misclassified examples: %d' % (y_test != y_pred).sum())
# Out:
# Misclassified examples: 1

# %%
from sklearn.metrics import accuracy_score
print('Accuracy: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.978

# %%
print('Accuracy: %.3f' % ppn.score(X_test_std, y_test))
# Out:
# Accuracy: 0.978

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, test_idx=None,
                          resolution=0.02):
  markers = ('s', 'x', 'o', '^', 'v')
  colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
  cmap = ListedColormap(colors[:len(np.unique(y))])

  x1_min, x1_max = X[:, 0].min() -1, X[:, 0].max() + 1
  x2_min, x2_max = X[:, 1].min() -1, X[:, 1].max() + 1
  xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                         np.arange(x2_min, x2_max, resolution))
  Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
  Z = Z.reshape(xx1.shape)
  plt.contourf(xx1, xx2, Z, alpha=0.03, cmap=cmap)
  plt.xlim(xx1.min(), xx1.max())
  plt.ylim(xx2.min(), xx2.max())

  for idx, cl in enumerate(np.unique(y)):
    plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                alpha=0.8, c=colors[idx],
                marker=markers[idx], label=cl,
                edgecolor='black')
  if test_idx:
    X_test, y_test = X[test_idx, :], y[test_idx]

    plt.scatter(X_test[:, 0], X_test[:, 1],
                edgecolor='black', alpha=1.0,
                linewidth=1, marker='o',
                s=100, label='test set')

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X=X_combined_std,
                      y=y_combined,
                      classifier=ppn,
                      test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_47600/4199807553.py:21: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4725, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4724 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4725     colors = mcolors.to_rgba_array(c)
#    4726 except (TypeError, ValueError) as err:
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/colors.py:498, in to_rgba_array(c, alpha)
#     497 if isinstance(c, str):
# --> 498     raise ValueError(f"{c!r} is not a valid color value.")
#     500 if len(c) == 0:
#
# ValueError: '' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 X_combined_std = np.vstack((X_train_std, X_test_std))
#       2 y_combined = np.hstack((y_train, y_test))
# ----> 3 plot_decision_regions(X=X_combined_std,
#       4                       y=y_combined,
#       5                       classifier=ppn,
#       6                       test_idx=range(105, 150))
#       7 plt.xlabel('petal length [standardized]')
#       8 plt.ylabel('petal width [standardized]')
#
# Cell In[45], line 28, in plot_decision_regions(X, y, classifier, test_idx, resolution)
#      25 if test_idx:
#      26   X_test, y_test = X[test_idx, :], y[test_idx]
# ---> 28   plt.scatter(X_test[:, 0], X_test[:, 1],
#      29               c='', edgecolor='black', alpha=1.0,
#      30               linewidth=1, marker='o',
#      31               s=100, label='test set')
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/pyplot.py:3939, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3919 @_copy_docstring_and_deprecators(Axes.scatter)
#    3920 def scatter(
#    3921     x: float | ArrayLike,
#    (...)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# -> 3939     __ret = gca().scatter(
#    3940         x,
#    3941         y,
#    3942         s=s,
#    3943         c=c,
#    3944         marker=marker,
#    3945         cmap=cmap,
#    3946         norm=norm,
#    3947         vmin=vmin,
#    3948         vmax=vmax,
#    3949         alpha=alpha,
#    3950         linewidths=linewidths,
#    3951         edgecolors=edgecolors,
#    3952         colorizer=colorizer,
#    3953         plotnonfinite=plotnonfinite,
#    3954         **({"data": data} if data is not None else {}),
#    3955         **kwargs,
#    3956     )
#    3957     sci(__ret)
#    3958     return __ret
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4918, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4915 if edgecolors is None:
#    4916     orig_edgecolor = kwargs.get('edgecolor', None)
#    4917 c, colors, edgecolors = \
# -> 4918     self._parse_scatter_color_args(
#    4919         c, edgecolors, kwargs, x.size,
#    4920         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4922 if plotnonfinite and colors is None:
#    4923     c = np.ma.masked_invalid(c)
#
# File ~/Documents/ml207/ml207-venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4734, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4731             raise invalid_shape_exception(c.size, xsize) from err
#    4732         # Both the mapping *and* the RGBA conversion failed: pretty
#    4733         # severe failure => one may appreciate a verbose feedback.
# -> 4734         raise ValueError(
#    4735             f"'c' argument must be a color, a sequence of colors, "
#    4736             f"or a sequence of numbers, not {c!r}") from err
#    4737 else:
#    4738     if len(colors) not in (0, 1, xsize):
#    4739         # NB: remember that a single color is also acceptable.
#    4740         # Besides *colors* will be an empty array if c == 'none'.
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not ''
